# %% [markdown]
# # **Manual Básico para Notebooks: Google Colab / Jupyter Notebook**
# ***Por: Ing. Ivonne Castaño Osorio***
#
# Este notebook es una guía práctica para aprender a usar **Google Colab** o **Jupyter Notebook**.

# %% [markdown]
# # **1. Introducción a los Notebooks**
# Los notebooks son entornos interactivos que permiten combinar código, texto y resultados en un solo documento. Son ampliamente usados en ciencia de datos y machine learning.
#
# *  **Google Colab:** Basado en Jupyter, gratuito y en la nube (no requiere instalación).
#
# *  **Jupyter Notebook:** Se ejecuta localmente (requiere Python y Jupyter instalados, o instalar Anaconda que incluye a ambos).

# %% [markdown]
# # **2. Configuración Básica**
# ## **Ejecutar una Celda**
# Las celdas pueden contener **código** o **texto (Markdown)**. Para ejecutarlas:
#
# * Haz clic en el botón ▶ o usa Shift + Enter.

# %%
# Ejemplo: Hola Mundo en Python
print("¡Bienvenido a Colab/Jupyter!")

# %% [markdown]
# ## **Tipos de Celdas**
# *  **Código:** Ejecuta comandos en Python.
#
# *  **Markdown:** Texto formateado (como este manual).

# %% [markdown]
# # **3. Formato de Texto en Celdas Markdown (Google Colab/Jupyter)**
#
# ## **1. Estilos Básicos de Texto**
# - **Negrita**: `**texto**` → **texto**
# - *Cursiva*: `*texto*` → *texto*
# - ~~Tachado~~: `~~texto~~` → ~~Tachado~~
# - `Código en línea`: `` `código` `` → `código`
#
# ## **2. Encabezados**
#
# # Título 1 (H1)
# ## Título 2 (H2)
# ### Título 3 (H3)
# #### Título 4 (H4)
#
#
# ## **3. Listas**
# ### **Listas No Ordenadas**
#
# - Item 1
# - Item 2
#   - Subitem 2.1 (sangría con 2 espacios)
#   - Subitem 2.2
#
#
# ### **Listas Ordenadas**
#
# 1. Primer paso
# 2. Segundo paso
#    1. Subpaso (sangría con 3 espacios)
#
#
# ### **Listas de Tareas (Checkboxes)**
#
# - [x] Tarea completada
# - [ ] Tarea pendiente
#
#
# ## **4. Superíndices y Subíndices**
# - **Superíndice**: `<sup>2</sup>` → x<sup>2</sup>.
# - **Subíndice**: `<sub>2</sub>` → H<sub>2</sub>.
#
# ## **5. Tablas**
# ```markdown
# | Nombre   | Edad | Ciudad    |
# |----------|------|-----------|
# | Juan     | 25   | Madrid    |
# | María    | 30   | Barcelona |
# ```
#
# ## **6. Imágenes**
# ### **Desde URL**
# ```markdown
# ![Texto alternativo](https://ejemplo.com/imagen.jpg)
# ```
# Ejemplo:
# ![Logo Python](https://www.python.org/static/community_logos/python-logo.png)
#
# ### **Desde tu Computadora (Google Colab)**
# 1. Sube la imagen a Colab:
#    ```python
#    from google.colab import files
#    uploaded = files.upload()  # Selecciona el archivo
#    ```
# 2. Inserta la imagen en Markdown:
#    ```markdown
#    ![Descripción](/content/nombre_imagen.jpg)
#    ```
#
# ## **7. Videos**
# ### **Videos Locales (Google Colab)**
# ```python
# from IPython.display import HTML
# HTML("""
# <video width="400" controls>
#   <source src="/content/video.mp4" type="video/mp4">
# </video>
# """)
# ```
#
# ### **Videos de YouTube**
# ```python
# from IPython.display import YouTubeVideo
# YouTubeVideo("8VFYs3Ot_aA?si=vppl7-birwQaQgYm")  # Reemplaza con el ID del video
# ```
#
# ## **8. Enlaces**
# ```markdown
# [Texto del enlace](https://www.ejemplo.com)
# ```
# Ejemplo:
# [Google](https://www.google.com)
#
# ## **9. Líneas Divisorias**
# ```markdown
# ---
# ```
# ---
#
# ## **10. Citas**
# ```markdown
# > "Esto es una cita de ejemplo."
# ```
# > "Esto es una cita de ejemplo."
#
# ## **11. Código en Bloques**
# \```python
# print("Hola Mundo")
# \```
# Resultado:
# ```python
# print("Hola Mundo")
# ```
#
# ---
#
# ### **Notas Finales**
# - En **Google Colab**, algunas funcionalidades avanzadas (como colores personalizados) requieren HTML/CSS.
# - Para **Jupyter Notebook**, el soporte es similar, pero la subida de archivos se hace manualmente.

# %% [markdown]
# ---

# %%
#Videos de YouTube
from IPython.display import YouTubeVideo
YouTubeVideo("8VFYs3Ot_aA?si=vppl7-birwQaQgYm")

# %% [markdown]
# ---

# %% [markdown]
# # **4. Comandos Esenciales en Google Colab/Jupyter Notebook**
#
# A continuación, se presenta una tabla ampliada con los comandos más útiles para gestionar la ejecución y el estado de las celdas en **Google Colab** y **Jupyter Notebook**.
#
# ---
#
# ### **📋 Tabla de Comandos para Gestión de Celdas y Ejecución**
#
# | **Comando**               | **Acción**                                                                 | **Disponibilidad**            |
# |---------------------------|---------------------------------------------------------------------------|-------------------------------|
# | `Ctrl + Enter`            | Ejecuta la celda actual.                                                  | ✅ Colab / ✅ Jupyter          |
# | `Shift + Enter`           | Ejecuta la celda actual y avanza a la siguiente.                          | ✅ Colab / ✅ Jupyter          |
# | `Alt + Enter`             | Ejecuta la celda actual e inserta una nueva celda debajo.                | ✅ Colab / ✅ Jupyter          |
# | `Ctrl + /`                | Comenta/descomenta líneas de código            | ❌ Colab / ✅ Jupyter (depende)|
# | `Ctrl + }`                | Comenta/descomenta líneas de código (en editores como VS Code).           | ✅ Colab / ❌ Jupyter          |
# | `Ctrl + M` + `D`          | **Borrar celda actual** (requiere confirmación en Colab).                 | ✅ Colab / ✅ Jupyter          |
# | `Esc` + `D` + `D`         | **Borrar celda actual** (sin confirmación).                               | ❌ Colab / ✅ Jupyter          |
# | `Ctrl + M` + `K`          | **Subir celda** (mover hacia arriba).                                     | ✅ Colab / ✅ Jupyter          |
# | `Ctrl + M` + `J`          | **Bajar celda** (mover hacia abajo).                                     | ✅ Colab / ✅ Jupyter          |
# | **Borrar resultados**     |                                                                           |                               |
# | `Ctrl + M` + `O`          | **Borrar salida de la celda actual** (Colab).                             | ✅ Colab / ❌ Jupyter          |
# | `Menú` → `Runtime` → `Restart and run all` | **Reiniciar kernel y ejecutar todo el notebook**. | ✅ Colab / ✅ Jupyter (como "Kernel → Restart & Run All") |
# | `Menú` → `Runtime` → `Restart runtime` | **Reiniciar kernel sin ejecutar celdas** (limpia caché).  | ✅ Colab / ✅ Jupyter (como "Kernel → Restart") |
# | `Menú` → `Runtime` → `Run all` | **Ejecutar todas las celdas en orden** (sin reiniciar).           | ✅ Colab / ✅ Jupyter          |
#
# ---
#
# ### **🔹 Notas Adicionales**
#
# 1. **Borrar TODAS las salidas en Colab**:
#    - Ve a **`Menú → Edit → Clear all outputs`**.
#    - En Jupyter: **`Kernel → Restart & Clear Output`**.
#
# 2. **Borrar salida de una celda en particular**:
#    - En **Colab**: Haz clic en el ícono que aparece en la esquina inferior izquierda de la celda en la que aparece el resultado y selecciona `Borrar los resultados`.
#    - En **Jupyter**: Haz clic en `Cell → Current Outputs → Clear`.
#
# 3. **Reiniciar el kernel (eliminar variables en memoria)**:
#    - Útil si el notebook se comporta de manera inesperada por datos en caché.
#
# ---
#
# ### **📌 Ejemplo de Uso**
# Si quieres **reiniciar todo el notebook desde cero** (sin resultados guardados):
# 1. **Colab**: `Runtime → Restart runtime`.
# 2. **Jupyter**: `Kernel → Restart`.
#
# Para **ejecutar todas las celdas automáticamente después del reinicio**:
# - Usa **`Restart and run all`** (en Colab/Jupyter).
#
# ---

# %% [markdown]
# # **5. Comandos Mágicos**
# Son instrucciones especiales de Jupyter/Colab:

# %%
# Listar archivos en el directorio actual
# !ls

# %%
# Medir tiempo de ejecución
# %%time
for i in range(1000000):
    pass

# %% [markdown]
# # **6. Guardar y Exportar**
# Guardar en Google Drive:

# %%
from google.colab import drive
drive.mount('/content/drive')  # Conecta Colab con tu Drive

# %% [markdown]
# Exportar como PDF o .ipynb:
#
# *  File > Download .ipynb (para Jupyter/Colab).
#
# *  File > Print > Save as PDF.

# %% [markdown]
# # **7. Recursos Adicionales**
# - [Documentación de Google Colab](https://colab.research.google.com/)
# - [Tutorial oficial de Jupyter](https://jupyter.org/documentation)
